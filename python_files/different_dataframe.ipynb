# %%
import pandas as pd

# %% [markdown]
# # Read CSV file

# %%
df_csv = pd.read_csv('/Users/wempro/Desktop/FlutterDev/Minhaz/personal/data_science/data_science_basic/csv_files/nyc_weather.csv')

# %%
df_csv.head()
# Out:
#       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/16           38        23        52                 30.03
# 1  1/2/16           36        18        46                 30.02
# 2  1/3/16           40        21        47                 29.86
# 3  1/4/16           25         9        44                 30.05
# 4  1/5/16           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %% [markdown]
# # Read Excel file

# %%
df_ex = pd.read_excel('/Users/wempro/Desktop/FlutterDev/Minhaz/personal/data_science/data_science_basic/excel_files/weather.xlsx')

# %%
df_ex.head()
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0 2016-01-01           38        23        52                 30.03
# 1 2016-01-02           36        18        46                 30.02
# 2 2016-01-03           40        21        47                 29.86
# 3 2016-01-04           25         9        44                 30.05
# 4 2016-01-05           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333
