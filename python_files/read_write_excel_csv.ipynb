# %% [markdown]
# # Read CSV

# %%
import pandas as pd

# %%
csv_url = '/Users/wempro/Desktop/FlutterDev/Minhaz/personal/data_science/data_science_basic/csv_files/nyc_weather_updated.csv'

# %%
df  = pd.read_csv(csv_url, skiprows= 1)

# %%
df.head()
# Out:
#       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/16           38        23        52                 30.03
# 1  1/2/16           36        18        46                 30.02
# 2  1/3/16           40        21        47                 29.86
# 3  1/4/16           25         9        44                 30.05
# 4  1/5/16           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
no_header_csv = '/Users/wempro/Desktop/FlutterDev/Minhaz/personal/data_science/data_science_basic/csv_files/no_header.csv'

# %%
df3 = pd.read_csv(no_header_csv, header= None ,names = ['sdf', 'ssssdf', 'sfsfsfdf', 'sdsdfagasgf', 'asdvvvf', 'shasfgddf','sdfrafgfs', 'sdrharf', 'sdsfhref', 'ssfbsdfdf', 'asdf', 'asddfdf'])
df3.head(3)
# Out:
#       sdf  ssssdf  sfsfsfdf  sdsdfagasgf  asdvvvf  shasfgddf  sdfrafgfs  \
# 0  1/1/16      38        23           52    30.03         10        8.0
# 1  1/2/16      36        18           46    30.02         10        7.0
# 2  1/3/16      40        21           47    29.86         10        8.0
#
#   sdrharf  sdsfhref ssfbsdfdf  asdf  asddfdf
# 0       0         5       NaN   281      NaN
# 1       0         3       NaN   275      NaN
# 2       0         1       NaN   277      NaN

# %% [markdown]
# # Convert value into NAN

# %%
df4 = pd.read_csv(csv_url, nrows= 3, skiprows= 1, na_values=['not available' ,0])
df4
# Out:
#       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/16           38        23        52                 30.03
# 1  1/2/16           36        18        46                 30.02
# 2  1/3/16           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH  PrecipitationIn  CloudCover  Events  \
# 0               10             8              NaN           5     NaN
# 1               10             7              NaN           3     NaN
# 2               10             8              NaN           1     NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %% [markdown]
# # Convert multiple value into NAN

# %%
df5 = pd.read_csv(csv_url, skiprows= 1, na_values={
    'PrecipitationIn': ['not available', 0, 'T'], # Convert both 0 and T to NaN value
    'CloudCover': ['not available', 1],
})
df5.head(3)
# Out:
#       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/16           38        23        52                 30.03
# 1  1/2/16           36        18        46                 30.02
# 2  1/3/16           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH  PrecipitationIn  CloudCover Events  \
# 0               10           8.0              NaN         5.0    NaN
# 1               10           7.0              NaN         3.0    NaN
# 2               10           8.0              NaN         NaN    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
print('sdfs')
# Out:
# sdfs
