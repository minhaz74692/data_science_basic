# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/wempro/Downloads/nyc_weather.csv')

# %%
df.set_index('EST', inplace = True)

# %%
df.head()
# Out:
#           Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016           38        23        52                 30.03
# 1/2/2016           36        18        46                 30.02
# 1/3/2016           40        21        47                 29.86
# 1/4/2016           25         9        44                 30.05
# 1/5/2016           20        -3        41                 30.57
#
#           VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# EST
# 1/1/2016               10           8.0               0           5    NaN
# 1/2/2016               10           7.0               0           3    NaN
# 1/3/2016               10           8.0               0           1    NaN
# 1/4/2016               10           9.0               0           3    NaN
# 1/5/2016               10           5.0               0           0    NaN
#
#           WindDirDegrees
# EST
# 1/1/2016             281
# 1/2/2016             275
# 1/3/2016             277
# 1/4/2016             345
# 1/5/2016             333

# %%
df.loc['1/4/2016']
# Out:
# Temperature                25
# DewPoint                    9
# Humidity                   44
# Sea Level PressureIn    30.05
# VisibilityMiles            10
# WindSpeedMPH              9.0
# PrecipitationIn             0
# CloudCover                  3
# Events                    NaN
# WindDirDegrees            345
# Name: 1/4/2016, dtype: object

# %%
df.reset_index(inplace= True)

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.set_index('Temperature', inplace=True)

# %%
df.head()
# Out:
#                   EST  DewPoint  Humidity  Sea Level PressureIn  \
# Temperature
# 38           1/1/2016        23        52                 30.03
# 36           1/2/2016        18        46                 30.02
# 40           1/3/2016        21        47                 29.86
# 25           1/4/2016         9        44                 30.05
# 20           1/5/2016        -3        41                 30.57
#
#              VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# Temperature
# 38                        10           8.0               0           5    NaN
# 36                        10           7.0               0           3    NaN
# 40                        10           8.0               0           1    NaN
# 25                        10           9.0               0           3    NaN
# 20                        10           5.0               0           0    NaN
#
#              WindDirDegrees
# Temperature
# 38                      281
# 36                      275
# 40                      277
# 25                      345
# 20                      333

# %%
df.reset_index(inplace=True)

# %%
df.set_index('Events', inplace=True)

# %%
df.tail()
# Out:
#         Temperature        EST  DewPoint  Humidity  Sea Level PressureIn  \
# Events
# Rain             41  1/27/2016        22        45                 30.03
# NaN              37  1/28/2016        20        51                 29.90
# NaN              36  1/29/2016        21        50                 29.58
# NaN              34  1/30/2016        16        46                 30.01
# NaN              46  1/31/2016        28        52                 29.90
#
#         VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# Events
# Rain                 10           7.0               T           3
# NaN                  10           5.0               0           1
# NaN                  10           8.0               0           4
# NaN                  10           7.0               0           0
# NaN                  10           5.0               0           0
#
#         WindDirDegrees
# Events
# Rain               311
# NaN                234
# NaN                298
# NaN                257
# NaN                241

# %%
df.loc['Snow']
# Out:
#         Temperature        EST  DewPoint  Humidity  Sea Level PressureIn  \
# Events
# Snow             25  1/18/2016         6        53                 29.83
# Snow             26  1/22/2016         6        41                 30.21
# Snow             28  1/24/2016        11        53                 29.92
#
#         VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# Events
# Snow                  9          12.0               T           2
# Snow                  9           NaN            0.01           3
# Snow                  8           6.0               T           3
#
#         WindDirDegrees
# Events
# Snow               293
# Snow                34
# Snow               327
